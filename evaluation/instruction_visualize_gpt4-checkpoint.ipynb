# %% [markdown]
# # Instruction Tuning with GPT-4
#
# This notebook is developed to produce the pie chart html/figure in the GPT-4-LLM paper. It analyzes the GPT4 output by following the instructions.
#
# ```
# ``Instruction Tuning with GPT-4'' (https://arxiv.org/abs/2304.03277)
# Baolin Peng*, Chunyuan Li*, Pengcheng He*, Michel Galley, Jianfeng Gao (*Equal Contribution)
# ```
#
# - Project: https://instruction-tuning-with-gpt-4.github.io/
# - Github Repo: https://github.com/Instruction-Tuning-with-GPT-4/GPT-4-LLM
#
# Please submit an issue in the github repo, if you have any questions.
#
#
#
# *Note: The original script from [self-instruct repo](https://github.com/yizhongw/self-instruct/blob/main/self_instruct/instruction_visualize.ipynb). The script uses Berkeley Neural Parser to parse the generated instructions, and visualize the results using Plotly. Please make sure to install benepar following their documentation [here](https://github.com/nikitakit/self-attentive-parser#installation).*

# %%
import benepar, spacy

# !python -m spacy download en_core_web_md
nlp = spacy.load('en_core_web_md')
doc = nlp("The time for action is now. It's never too late to do something.")

import matplotlib.pyplot as plt
# Out:
# Collecting en-core-web-md==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.7.1/en_core_web_md-3.7.1-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 52.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from en-core-web-md==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.3.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.4.2)
# Requirement already satisfied: jinja2 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.5.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/xinlu/anaconda3/envs/llm/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %% [markdown]
# ## 1. Generate Verb-Noun Pairs for GPT4 Output
#
# :warning: Warning: It takes 20 minutes to run the entire pre-processing, and save it into a csv file. You consider to skip processing, and load our pre-process Verb-Noun CSV file in the next step.

# %%
def find_root_verb_and_its_dobj(tree_root):
    # first check if the current node and its children satisfy the condition
    if tree_root.pos_ == "VERB":
        for child in tree_root.children:
            if child.dep_ == "dobj" and child.pos_ == "NOUN":
                return tree_root.lemma_, child.lemma_
        return tree_root.lemma_, None
    # if not, check its children
    for child in tree_root.children:
        return find_root_verb_and_its_dobj(child)
    # if no children satisfy the condition, return None
    return None, None

def find_root_verb_and_its_dobj_in_string(s):
    doc = nlp(s)
    first_sent = list(doc.sents)[0]
    return find_root_verb_and_its_dobj(first_sent.root)

find_root_verb_and_its_dobj_in_string("Write me a story about education.")
# Out:
# ('write', 'story')

# %%
import json
with open("./dataset/medical_chat_data.json", 'r') as f:
    data_general = json.load(f)
with open("./dataset/quora_chat_data.json", 'r') as f:
    data_general += json.load(f)
gpt4_machine_generated_tasks=[]
for data in data_general:
    task={}
    task['instruction']=data['input'].split('\n[|Human|]')[1].split('\n[|AI|]')[0].strip()
    gpt4_machine_generated_tasks.append(task)

# %%
import pandas as pd
import json
import tqdm


generated_data_path = "./dataset/pmc_llama_instructions/release.json"

with open(generated_data_path, 'r') as fin:
    gpt4_machine_generated_tasks = json.load(fin)

len(generated_data_path )
# print(gpt4_machine_generated_tasks[0])

instruction_outputs = set([task["instruction"] for task in gpt4_machine_generated_tasks]) # if you are interested in studying the instructions, please change the task key
print(len(instruction_outputs))

raw_phrases = []
for out in tqdm.tqdm(instruction_outputs):
    try:
        verb, noun = find_root_verb_and_its_dobj_in_string(out)
        raw_phrases.append({
            "verb": verb,
            "noun": noun,
            "instruction_output": out
        })
    except Exception as e:
        print(e)
        print(out)
# Out:
# 70
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 70/70 [00:00<00:00, 194.64it/s]

# %%
len(raw_phrases)
raw_phrases = pd.DataFrame(raw_phrases)
raw_phrases.to_csv(r'data/pmc_verb_noun_output.csv')

# %% [markdown]
# ## 2. Pie Chart Creation on Verb-Noun
#
# Load our pre-process Verb-Noun CSV file, and create the html file with plotly

# %%
import pandas as pd
raw_phrases = pd.read_csv(r'data/pmc_verb_noun_output.csv')
raw_phrases = pd.DataFrame(raw_phrases)
phrases = pd.DataFrame(raw_phrases).dropna()
count_list = phrases[["verb", "noun"]].groupby(["verb", "noun"]).size().sort_values(ascending=False)

# %%
len(count_list)
# count_list[:25]

# count_list[:25].plot.barh()
# plt.ylabel('verb, noun')
# plt.xlabel('frequency')
# plt.show()
# Out:
# 6

# %%
top_verbs = phrases[["verb"]].groupby(["verb"]).size().nlargest(20).reset_index()

df = phrases[phrases["verb"].isin(top_verbs["verb"].tolist())]
# df = df[~df["noun"].isin(["I", "what"])]
# df = phrases
# df[~df["verb"].isin(top_verbs["verb"].tolist())]["verb"] = "other"
# df[~df["verb"].isin(top_verbs["verb"].tolist())]["noun"] = "other"
df = df.groupby(["verb", "noun"]).size().reset_index().rename(columns={0: "count"}).sort_values(by=["count"], ascending=False)
# df = df[df["count"] > 10]
df = df.groupby("verb").apply(lambda x: x.sort_values("count", ascending=False).head(4)).reset_index(drop=True)
df
# Out:
#        verb         noun  count
# 0   address        query      7
# 1  evaluate  description      7
# 2   provide       answer      7
# 3   provide      insight      7
# 4   provide     response      7
# 5       use  description      7

# %%
# Calculate the total counts
total_counts = df['count'].sum()

# Add a new column for probability
df['probability'] = df['count'] / total_counts

import numpy as np

# Using the probabilities from the dummy data to calculate the entropy
# Entropy is calculated using the formula:
# H(X) = -sum(p(x) * log2(p(x))), where p(x) is the probability of each event

# Calculate entropy
entropy = -np.sum(df['probability'] * np.log2(df['probability']))
entropy
# Out:
# 2.584962500721156

# %%
import plotly.graph_objects as go
import plotly.express as px

# df["blank"] = "ROOT"
# df = phrases.groupby(["verb", "noun"]).size().sort_values(ascending=False).head(5).reset_index().rename(columns={0: "count"})

df = df[df["count"] > 10]
fig = px.sunburst(df, path=['verb', 'noun'], values='count')
# fig.update_layout(uniformtext=dict(minsize=10, mode='hide'))
fig.update_layout(
    margin=dict(l=0, r=0, t=0, b=0),
    font_family="Times New Roman",
    font_size=40  
)
# fig.show()
fig.write_html("data/baize_verb_noun_output.html")
# fig.savefig("output/verb_noun.pdf")

# %%
df['count'].sum()/52002
# Out:
# 0.22447213568708896

# %%
### view plot
import json
import pandas as pd

generated_data_path = "data/gpt4_generations/filtered_medical_instruction.jsonl"

dataset = [json.loads(l) for l in open(generated_data_path, "r")]
        # import pdb;pdb.set_trace()

len(dataset)


view_outputs = list([task["view"].lower()  for task in dataset]) # if you are interested in studying the instructions, please change the task key
type_outputs = list([task["type"].lower()  for task in dataset])
difficulty_outputs = list([task["difficulty"] for task in dataset])
topic_outputs = list([task["topic"] for task in dataset])

# %%
view_series = pd.Series(view_outputs)

# Use the value_counts() function to get the frequency of each name
view_counts =view_series.value_counts()

top_20_names = view_counts.head(20)

# Convert the Series to a DataFrame
df_view= pd.DataFrame({"Name": top_20_names.index, "Frequency": top_20_names.values})


# # Convert the Series to a DataFrame
# df_view = pd.DataFrame({"Name": view_counts.index, "Frequency": view_counts.values})

# Reset the index if you want to start from 0
df_view.reset_index(drop=True, inplace=True)

# %%
df_view
# Out:
#                       Name  Frequency
# 0          medical student       7219
# 1                  patient       6919
# 2                clinician       2530
# 3               pharmacist       2465
# 4        genetic counselor       1584
# 5                    nurse       1447
# 6                   expert       1368
# 7                physician       1288
# 8              radiologist       1252
# 9                  student       1209
# 10                  doctor       1204
# 11  public health official       1166
# 12              geneticist        910
# 13          epidemiologist        904
# 14              researcher        781
# 15   public health officer        756
# 16    public health expert        706
# 17          medical expert        673
# 18      medical researcher        640
# 19    general practitioner        568

# %%
# df_view= df_view[df_view["Frequency"] > 50]
fig = px.sunburst(df_view, path=['Name'], values='Frequency')
# fig.update_layout(uniformtext=dict(minsize=10, mode='hide'))
fig.update_layout(
    margin=dict(l=0, r=0, t=0, b=0),
    font_family="Times New Roman",
        font_size=80  
)
# fig.show()
fig.write_html("data/instruction_view.html")

# %%
type_series = pd.Series(type_outputs)

# Use the value_counts() function to get the frequency of each name
type_counts =type_series.value_counts()


# # Get the top 20 names based on frequency
top_10_names = type_counts.head(20)

# # Convert the Series to a DataFrame
df_type = pd.DataFrame({"Name": top_10_names.index, "Frequency": top_10_names.values})
#df_type = pd.DataFrame({"Name": type_counts.index, "Frequency": type_counts.values})
# Reset the index if you want to start from 0
df_type.reset_index(drop=True, inplace=True)


df_type
# Out:
#                       Name  Frequency
# 0          text generation       9142
# 1                     chat       9082
# 2                 open q&a       7278
# 3     single-hop reasoning       6624
# 4            summarization       5277
# 5   multiple-hop reasoning       4961
# 6           classification       4436
# 7          usmle style q&a       3545
# 8                  rewrite       3267
# 9      multiple-choice q&a       3010
# 10                rewrites       1491
# 11          summarizations       1045
# 12         classifications        866
# 13     multiple choice q&a        621
# 14  multiple hop reasoning        570
# 15         usmle-style q&a        497
# 16    single hop reasoning        291
# 17     multi-hop reasoning        272
# 18                 summary        176
# 19          open-ended q&a        127

# %%
# df_type= df_type[df_type["Frequency"] > 50]
fig = px.sunburst(df_type, path=['Name'], values='Frequency')
# fig.update_layout(uniformtext=dict(minsize=10, mode='hide'))
fig.update_layout(
    margin=dict(l=0, r=0, t=0, b=0),
    font_family="Times New Roman",
        font_size=80  
)
# fig.show()
fig.write_html("data/instruction_type.html")

# %%
df_view["Frequency"].sum()/len(dataset)
# Out:
# 0.553053613053613

# %%
df_type["Frequency"].sum()/len(dataset)
# Out:
# 0.9724630924630925

# %%
df_type["Frequency"].sum()
# Out:
# 56622

# %%
view_series = pd.Series(topic_outputs)

# Use the value_counts() function to get the frequency of each name
view_counts =view_series.value_counts()

top_20_names = view_counts.head(20)

# Convert the Series to a DataFrame
df_view= pd.DataFrame({"Name": top_20_names.index, "Frequency": top_20_names.values})


# # Convert the Series to a DataFrame
# df_view = pd.DataFrame({"Name": view_counts.index, "Frequency": view_counts.values})

# Reset the index if you want to start from 0
df_view.reset_index(drop=True, inplace=True)

# %%
df_view
# Out:
#                  Name  Frequency
# 0        Pharmacology       5690
# 1        Epidemiology       5633
# 2     Pathophysiology       5309
# 3            Genetics       5183
# 4   Medical Education       4239
# 5             Anatomy       3929
# 6            Diseases       3718
# 7           Treatment       2750
# 8           Diagnoses       2617
# 9           Neurology       1017
# 10         Cardiology        743
# 11          Radiology        707
# 12         Pediatrics        649
# 13           Oncology        629
# 14         Immunology        590
# 15      Mental Health        499
# 16        Dermatology        486
# 17      Endocrinology        474
# 18          Diagnosis        458
# 19  Medical education        456

# %%
# df_view= df_view[df_view["Frequency"] > 50]


# import plotly.graph_objects as go
import plotly.express as px

fig = px.sunburst(df_view, path=['Name'], values='Frequency')
# fig.update_layout(uniformtext=dict(minsize=10, mode='hide'))
fig.update_layout(
    margin=dict(l=0, r=0, t=0, b=0),
    font_family="Times New Roman",
        font_size=80  
)
# fig.show()
fig.write_html("data/instruction_topic.html")
